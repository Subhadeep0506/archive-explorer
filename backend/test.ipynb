# %%
# Out:
# Running cells with '.venv (Python 3.13.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/703381054/Documents/ArxiverApp/backend/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
